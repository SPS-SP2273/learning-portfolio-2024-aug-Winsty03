# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os, glob, shutil

# %%
month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

old_file = 'oct-08_singapore.txt'

parts = old_file.split('-')
print(old_file, parts)
print(parts[0])
month_country = parts[1].split('_')
print(month_country[0])
number_month = month_dict[parts[0]]
print(number_month)
new_file = f'{number_month}-{month_country[0]}-{month_country[1]}'

print(new_file)
# Out:
# oct-08_singapore.txt ['oct', '08_singapore.txt']
# oct
# 08
# 10
# 10-08-singapore.txt

# %%
#Task 1 

month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

old_file = 'oct-08_singapore.txt'

parts = old_file.split('-')

month_country = parts[1].split('_')

number_month = month_dict[parts[0]]

new_file = f'{number_month}-{month_country[0]}-{month_country[1]}'

print(new_file)
# Out:
# 10-08-singapore.txt

# %%
#Task 2 
month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):

    parts = old_file_name.split('-')
    
    month_country = parts[1].split('_')

    number_month = month_dict[parts[0]]

    new_file = f'{number_month}-{month_country[0]}-{month_country[1]}'
    
    return new_file

rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
#task 3 
month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
   
    parts = old_file_name.split('-')
    
    month_country = parts[1].split('_')

    number_month = month_dict[parts[0]]

    new_file = f'{number_month}-{month_country[0]}-{month_country[1]}'
    
    return new_file

file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for file in file_list:
    new_file_list = rename_my_file(file)
    print(f'{file} ----> {new_file_list}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %%
#task 4 

month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
   
    parts = old_file_name.split('-')
    
    month_country = parts[1].split('_')

    number_month = month_dict[parts[0]]

    new_file = f'{number_month}-{month_country[0]}-{month_country[1]}'
    
    return new_file


glob.glob('os-collaboration-exercise-data\\*.txt')

text_file = glob.glob('os-collaboration-exercise-data\\*.txt')

just_text_file = [x.split(os.path.sep)[-1] for x in text_file]  #gets all the .txt files in the folder without the 'os-collaboration-exercise-data'

for file in just_text_file:
    new_file_list = rename_my_file(file)
 #   print(f'{file} ----> {new_file_list}')


[os.path.join('os-collaboration-exercise-data',rename_my_file(x)) for x in just_text_file]
# Out:
# ['os-collaboration-exercise-data\\04-01-melbourne.txt',
#  'os-collaboration-exercise-data\\04-01-shanghai.txt',
#  'os-collaboration-exercise-data\\04-01-singapore.txt',
#  'os-collaboration-exercise-data\\04-02-cairo.txt',
#  'os-collaboration-exercise-data\\04-02-jakarta.txt',
#  'os-collaboration-exercise-data\\04-02-karachi.txt',
#  'os-collaboration-exercise-data\\04-02-shanghai.txt',
#  'os-collaboration-exercise-data\\04-03-manila.txt',
#  'os-collaboration-exercise-data\\04-03-osaka.txt',
#  'os-collaboration-exercise-data\\04-03-singapore.txt',
#  'os-collaboration-exercise-data\\04-03-tokyo.txt',
#  'os-collaboration-exercise-data\\04-04-manila.txt',
#  'os-collaboration-exercise-data\\04-04-melbourne.txt',
#  'os-collaboration-exercise-data\\04-04-shanghai.txt',
#  'os-collaboration-exercise-data\\04-04-singapore.txt',
#  'os-collaboration-exercise-data\\04-05-karachi.txt',
#  'os-collaboration-exercise-data\\04-05-melbourne.txt',
# ...

# %%
filepath = '..\\6.2_files,_folders_&_os__exercises'

os.path.exists(filepath)
# Out:
# True

# %%
with open('os-collaboration-exercise-data\\apr-01_melbourne.txt', 'r') as file:
    file_content = file.read()
    
print(file_content)
# Out:
# 1:39:07 AM	8090.86
# 12:49:45 PM	8365.94
# 6:18:18 PM	3252.45
# 3:28:37 AM	5246.24
# 11:02:40 PM	3140.12
# 5:18:24 PM	2107.62
# 6:00:00 AM	3189.35
# 11:04:57 PM	6704.97
# 7:30:15 PM	3459.44
# 4:48:15 AM	3520.55
# 5:38:43 PM	4815.24
# 10:23:25 PM	2825.63
# 5:08:27 AM	8261.26
# 3:50:03 PM	1742.21
# 9:14:22 AM	3248.64
# 6:13:13 AM	9375.24
# 5:13:47 AM	3275.13
# 7:27:25 AM	585.53
# 11:25:38 AM	9598.57
# 7:24:17 PM	5473.75
# 1:59:02 AM	6383.99
# 11:07:13 AM	4145.84
# 11:04:52 AM	3104.79
# 11:37:13 AM	8829.98
# 9:41:15 AM	2518.26
# 7:00:15 AM	7915.73
# 11:58:53 PM	5035.75
# 1:47:59 PM	8985.32
# 4:41:58 PM	2807.78
# 7:48:00 AM	407.67
# 5:57:25 AM	9344.48
# 1:20:53 PM	3565.26
# 5:33:46 AM	2991.54
# 11:10:12 PM	284.37
# 9:31:52 AM	5082.17
# 2:32:55 PM	2538.73
# 5:52:08 PM	6085.18
# 1:28:23 AM	3997.14
# 12:41:24 AM	5569.65
# 12:29:24 PM	5485.24
# 5:01:21 AM	4306.4
# 5:55:08 PM	8931.82

# %%
glob.glob('*/*.txt')
# Out:
# ['os-collaboration-exercise-data\\apr-01_melbourne.txt',
#  'os-collaboration-exercise-data\\apr-01_shanghai.txt',
#  'os-collaboration-exercise-data\\apr-01_singapore.txt',
#  'os-collaboration-exercise-data\\apr-02_cairo.txt',
#  'os-collaboration-exercise-data\\apr-02_jakarta.txt',
#  'os-collaboration-exercise-data\\apr-02_karachi.txt',
#  'os-collaboration-exercise-data\\apr-02_shanghai.txt',
#  'os-collaboration-exercise-data\\apr-03_manila.txt',
#  'os-collaboration-exercise-data\\apr-03_osaka.txt',
#  'os-collaboration-exercise-data\\apr-03_singapore.txt',
#  'os-collaboration-exercise-data\\apr-03_tokyo.txt',
#  'os-collaboration-exercise-data\\apr-04_manila.txt',
#  'os-collaboration-exercise-data\\apr-04_melbourne.txt',
#  'os-collaboration-exercise-data\\apr-04_shanghai.txt',
#  'os-collaboration-exercise-data\\apr-04_singapore.txt',
#  'os-collaboration-exercise-data\\apr-05_karachi.txt',
#  'os-collaboration-exercise-data\\apr-05_melbourne.txt',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Winston\\Documents\\GitHub\\learning-portfolio-2024-aug-Winsty03\\6.2_files,_folders_&_os__exercises'
